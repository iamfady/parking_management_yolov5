# %%
import cv2
import torch
import numpy as np

# %%
def POINTS(event, x, y, flags, param):
    
    if event == cv2.EVENT_LBUTTONDOWN :
        colorsBGR = [x, y]
        print(colorsBGR)

# %%
cv2.namedWindow('FRAME')
#cv2.setMouseCallback('FRAME', POINTS)

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /Users/fady/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-3-23 Python-3.11.5 torch-2.2.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID') #use any fourcc type to improve quality for the saved video

# %%
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640,480)) #Video settings

# %%
cap=cv2.VideoCapture('parking.mp4')

# %%
area = [(26,433),(9,516),(389, 492),(786,419),(720,368)]

# %%
while True:
    
    ret,frame=cap.read()
    if not ret:
        break
    frame=cv2.resize(frame,(1020,600))

    results=model(frame)
    #print(results.xyxy[0])
    #print(results.pandas().xyxy[0])
    #results.pandas()
    points = []
    for index, row in results.pandas().xyxy[0].iterrows():
        #print(row)
        x1 = int(row['xmin'])
        y1 = int(row['ymin'])
        x2 = int(row['xmax'])
        y2 = int(row['ymax'])
        d=(row['name'])
        cx=int(x1+x2)//2
        cy=int(y1+y2)//2
        if 'car' in d:
            results = cv2.pointPolygonTest(np.array(area,np.int32),(cx,cy),False)
            #print(results)
            if results>=0:
                cv2.rectangle(frame,(x1,y1),(x2,y2),(0,0,255),3)
                cv2.putText(frame,str(d),(x1,y1),cv2.FONT_HERSHEY_PLAIN,2,(255,0,0),2)
                points.append([cx])
    a = len(points)
    #print(points)
    cv2.polylines(frame,[np.array(area,np.int32)],True,(0,255,0),2)
    cv2.putText(frame,'number of cars in parking ='+str(a),(50,80),cv2.FONT_HERSHEY_PLAIN,2,(0,0,255),2)
                
    cv2.imshow("FRAME",frame)
    out.write(frame) #save your video
    cv2.setMouseCallback("FRAME",POINTS)
   

    if cv2.waitKey(1)==27:
        break
cap.release()
out.release()

cv2.destroyAllWindows()
# Out:
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e9c184 _ZN15MenuBarInstance14EnableAutoShowEv + 56
# 4   HIToolbox                           0x00000001b4e3f310 SetMenuBarObscured + 372
# 5   HIToolbox                           0x00000001b4e3eee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 6   HIToolbox                           0x00000001b4e38fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 7   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 8   HIToolbox                           0x00000001b4e3896c AcquireEventFromQueue + 432
# 9   HIToolbox                           0x00000001b4e27c84 ReceiveNextEventCommon + 320
# 10  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 11  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 12  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 13  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 14  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 15  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 16  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 17  python3.11                          0x00000001041a6928 cfunction_call + 60
# 18  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 19  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 20  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 21  python3.11                          0x0000000104251b64 builtin_exec + 332
# 22  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 23  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 24  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 25  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 26  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 27  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 28  python3.11                          0x000000010416104c gen_send + 52
# 29  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 30  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 31  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 32  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 33  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 34  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 35  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 36  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 37  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 38  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 39  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 40  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 41  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 42  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 43  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 44  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 45  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 46  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 47  python3.11                          0x00000001042b1c88 context_run + 92
# 48  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 49  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 50  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 51  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 52  python3.11                          0x0000000104251b64 builtin_exec + 332
# 53  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 54  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 55  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 56  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 57  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 58  python3.11                          0x00000001040db99c main + 56
# 59  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4ea0380 _ZL19AutoShowHideHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 104
# 4   HIToolbox                           0x00000001b4e004c0 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 1092
# 5   HIToolbox                           0x00000001b4dff940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 6   HIToolbox                           0x00000001b4dff7d0 SendEventToEventTargetWithOptions + 44
# 7   HIToolbox                           0x00000001b4e3f9cc _ZL29ToolboxEventDispatcherHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 472
# 8   HIToolbox                           0x00000001b4e00968 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 2284
# 9   HIToolbox                           0x00000001b4dff940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 10  HIToolbox                           0x00000001b4e15bb8 SendEventToEventTarget + 40
# 11  AppKit                              0x00000001ae9ccf00 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 2044
# 12  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 13  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.11                          0x00000001041a6928 cfunction_call + 60
# 17  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 18  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 19  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 20  python3.11                          0x0000000104251b64 builtin_exec + 332
# 21  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 22  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 23  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 24  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 25  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 26  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 27  python3.11                          0x000000010416104c gen_send + 52
# 28  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 29  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 30  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 31  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 32  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 33  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 35  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 36  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 37  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 38  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 39  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 42  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 43  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 44  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 45  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 46  python3.11                          0x00000001042b1c88 context_run + 92
# 47  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 48  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 49  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 50  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 51  python3.11                          0x0000000104251b64 builtin_exec + 332
# 52  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 53  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 54  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 55  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 56  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 57  python3.11                          0x00000001040db99c main + 56
# 58  dyld                                0x00000001ab33fe50 start + 2544
# [119, 69]
# [139, 116]
# 1   HIToolbox                           0x00000001b4e9c5c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001b4e098c8 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1196
# 3   HIToolbox                           0x00000001b4e9c004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 4   AppKit                              0x00000001aec8bd30 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 5   AppKit                              0x00000001aeb2193c -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 6   CoreFoundation                      0x00000001ab73e560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 7   CoreFoundation                      0x00000001ab7dc044 ___CFXRegistrationPost_block_invoke + 88
# 8   CoreFoundation                      0x00000001ab7dbf8c _CFXRegistrationPost + 440
# 9   CoreFoundation                      0x00000001ab70fb64 _CFXNotificationPost + 708
# 10  Foundation                          0x00000001ac5ff38c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 11  AppKit                              0x00000001aec8c2b4 spacesNotificationHandler + 96
# 12  SkyLight                            0x00000001b0379214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 13  SkyLight                            0x00000001b0377e10 CGSSnarfAndDispatchDatagrams + 808
# 14  SkyLight                            0x00000001b069fa9c SLSGetNextEventRecordInternal + 344
# 15  SkyLight                            0x00000001b04a0fb0 SLEventCreateNextEvent + 16
# 16  HIToolbox                           0x00000001b4e34b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 17  HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 18  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 19  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 20  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 21  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 22  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 23  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 24  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 25  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 26  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 27  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 28  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 29  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 30  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 31  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 32  python3.11                          0x00000001041a6928 cfunction_call + 60
# 33  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 34  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 35  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 36  python3.11                          0x0000000104251b64 builtin_exec + 332
# 37  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 38  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 39  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 43  python3.11                          0x000000010416104c gen_send + 52
# 44  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 45  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 46  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 47  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 48  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 49  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 50  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 51  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 52  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 53  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 54  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 55  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 56  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 57  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 58  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 59  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 60  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 61  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 62  python3.11                          0x00000001042b1c88 context_run + 92
# 63  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 64  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 65  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 66  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 67  python3.11                          0x0000000104251b64 builtin_exec + 332
# 68  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 69  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 70  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 71  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 72  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 73  python3.11                          0x00000001040db99c main + 56
# 74  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x00000001041a6928 cfunction_call + 60
# 25  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104251b64 builtin_exec + 332
# 29  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 31  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 33  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 35  python3.11                          0x000000010416104c gen_send + 52
# 36  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 39  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 43  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 45  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 47  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 52  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x00000001042b1c88 context_run + 92
# 55  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104251b64 builtin_exec + 332
# 60  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 65  python3.11                          0x00000001040db99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x00000001041a6928 cfunction_call + 60
# 25  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104251b64 builtin_exec + 332
# 29  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 31  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 33  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 35  python3.11                          0x000000010416104c gen_send + 52
# 36  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 39  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 43  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 45  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 47  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 52  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x00000001042b1c88 context_run + 92
# 55  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104251b64 builtin_exec + 332
# 60  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 65  python3.11                          0x00000001040db99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x00000001041a6928 cfunction_call + 60
# 25  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104251b64 builtin_exec + 332
# 29  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 31  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 33  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 35  python3.11                          0x000000010416104c gen_send + 52
# 36  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 39  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 43  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 45  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 47  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 52  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x00000001042b1c88 context_run + 92
# 55  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104251b64 builtin_exec + 332
# 60  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 65  python3.11                          0x00000001040db99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x00000001041a6928 cfunction_call + 60
# 25  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104251b64 builtin_exec + 332
# 29  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 31  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 33  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 35  python3.11                          0x000000010416104c gen_send + 52
# 36  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 39  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 43  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 45  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 47  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 52  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x00000001042b1c88 context_run + 92
# 55  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104251b64 builtin_exec + 332
# 60  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 65  python3.11                          0x00000001040db99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
# 1   HIToolbox                           0x00000001b4fc2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b4e9c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b4e0930c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001b4e9c8a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001b4dffcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001b4e33bb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001b4e35340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001b4e34c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001b4e34ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x00000001ab779410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x00000001ab749f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x00000001ab749eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x00000001ab7488a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x00000001ab747878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001b4e27fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001b4e27c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001b4e27b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x00000001ae9cd84c _DPSNextEvent + 632
# 19  AppKit                              0x00000001ae9cc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x00000001269c71d8 cvWaitKey + 476
# 21  cv2.abi3.so                         0x00000001269c1328 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x00000001269c1420 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x0000000125ebdd4c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.11                          0x00000001041a6928 cfunction_call + 60
# 25  python3.11                          0x00000001042898a4 _PyEval_EvalFrameDefault + 197284
# 26  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 27  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 28  python3.11                          0x0000000104251b64 builtin_exec + 332
# 29  python3.11                          0x000000010428d2f8 _PyEval_EvalFrameDefault + 212216
# 30  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 31  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 32  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 33  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 34  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 35  python3.11                          0x000000010416104c gen_send + 52
# 36  python3.11                          0x000000010428db30 _PyEval_EvalFrameDefault + 214320
# 37  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 38  python3.11                          0x0000000104149af0 method_vectorcall + 272
# 39  python3.11                          0x000000010428e5b0 _PyEval_EvalFrameDefault + 217008
# 40  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 41  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 42  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 43  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 44  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 45  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 46  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 47  python3.11                          0x00000001042642e8 _PyEval_EvalFrameDefault + 44264
# 48  python3.11                          0x00000001041608f4 gen_send_ex2 + 204
# 49  _asyncio.cpython-311-darwin.so      0x0000000104e60370 task_step_impl + 440
# 50  _asyncio.cpython-311-darwin.so      0x0000000104e60128 task_step + 68
# 51  _asyncio.cpython-311-darwin.so      0x0000000104e60c30 task_wakeup + 136
# 52  python3.11                          0x00000001041a72f8 cfunction_vectorcall_O + 92
# 53  python3.11                          0x00000001042b1dc4 _PyObject_VectorcallTstate.4603 + 88
# 54  python3.11                          0x00000001042b1c88 context_run + 92
# 55  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 56  python3.11                          0x000000010428e65c _PyEval_EvalFrameDefault + 217180
# 57  python3.11                          0x0000000104256b88 _PyEval_Vector + 464
# 58  python3.11                          0x0000000104256928 PyEval_EvalCode + 248
# 59  python3.11                          0x0000000104251b64 builtin_exec + 332
# 60  python3.11                          0x00000001041a75d8 cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x00000001042896b0 _PyEval_EvalFrameDefault + 196784
# 62  python3.11                          0x0000000104143e28 _PyFunction_Vectorcall + 476
# 63  python3.11                          0x00000001043127f8 pymain_run_module + 212
# 64  python3.11                          0x0000000104312290 Py_RunMain + 1292
# 65  python3.11                          0x00000001040db99c main + 56
# 66  dyld                                0x00000001ab33fe50 start + 2544
